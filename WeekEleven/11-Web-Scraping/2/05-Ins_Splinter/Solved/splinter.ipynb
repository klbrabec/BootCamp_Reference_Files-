# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 107.0.5304
# [WDM] - Get LATEST driver version for 107.0.5304
# [WDM] - Driver [C:\Users\19198\.wdm\drivers\chromedriver\win32\107.0.5304.62\chromedriver.exe] found in cache

# %%
url = "https://stackoverflow.com/questions/tagged/python?sort=MostVotes&edited=true"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
question_list = []

# %%
def get_summary():
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    question_divs = soup.find_all('div', class_="s-post-summary")
    
    for question in question_divs:
        summary = question.find("a", class_="s-link").text
        votes = question.find("span", class_="s-post-summary--stats-item-number").text
        excerpt = question.find("div", class_="s-post-summary--content-excerpt").text.strip()
        question_dict = {
            "summary": summary,
            "votes": votes,
            "excerpt": excerpt
        }
        question_list.append(question_dict)

# %%
for _ in range(5):
    get_summary()
    browser.links.find_by_partial_text('Next').click()

# %%
question_list
# Out:
# [{'summary': 'What does the "yield" keyword do?',
#   'votes': '12329',
#   'excerpt': "What is the use of the yield keyword in Python? What does it do?\nFor example, I'm trying to understand this code1:\ndef _get_child_candidates(self, distance, min_dist, max_dist):\n    if self._leftchild ..."},
#  {'summary': 'What does if __name__ == "__main__": do in Python?',
#   'votes': '7788',
#   'excerpt': 'What does this do, and why should one include the if statement?\nif __name__ == "__main__":\n    print("Hello, World!")\nIf you are trying to close a question where someone should be ...'},
#  {'summary': 'Does Python have a ternary conditional operator?',
#   'votes': '7527',
#   'excerpt': 'Is there a ternary conditional operator in Python?'},
#  {'summary': 'What are metaclasses in Python?',
#   'votes': '6998',
#   'excerpt': 'What are metaclasses? What are they used for?'},
#  {'summary': 'How do I check whether a file exists without exceptions?',
#   'votes': '6809',
#   'excerpt': 'How do I check whether a file exists or not, without using the try statement?'},
#  {'summary': 'How do I merge two dictionaries in a single expression?',
#   'votes': '6507',
#   'excerpt': "I want to merge two dictionaries into a new dictionary.\nx = {'a': 1, 'b': 2}\ny = {'b': 3, 'c': 4}\nz = merge(x, y)\n\n>>> z\n{'a': 1, 'b': 3, 'c': 4}\n\nWhenever a key k is present in both ..."},
#  {'summary': 'How do I execute a program or call a system command?',
#   'votes': '5828',
#   'excerpt': "How do I call an external command within Python as if I'd typed it in a shell or command prompt?"},
#  {'summary': 'How can I safely create a nested directory?',
#   'votes': '5356',
#   'excerpt': 'How do I check if the directory into which a file is going to be written does exist, and if it does not, create the directory using Python?'},
#  {'summary': "Accessing the index in 'for' loops",
#   'votes': '4896',
#   'excerpt': 'How do I access the index while iterating over a sequence with a for loop?\nxs = [8, 23, 45]\n\nfor x in xs:\n    print("item #{} = {}".format(index, x))\n\nDesired output:\nitem #1 = 8\nitem #2 = ...'},
#  {'summary': 'How do I make a flat list out of a list of lists?',
#   'votes': '4885',
#   'excerpt': 'I have a list of lists like [[1, 2, 3], [4, 5, 6], [7], [8, 9]]. How can I flatten it to get [1, 2, 3, 4, 5, 6, 7, 8, 9]?\n\nIf your list of lists comes from a nested list comprehension, the problem can ...'},
#  {'summary': 'Difference between @staticmethod and @classmethod',
#   'votes': '4426',
#   'excerpt': 'What is the difference between a function decorated with @staticmethod and one decorated with @classmethod?'},
#  {'summary': 'Understanding slicing',
#   'votes': '4370',
#   'excerpt': 'I need a good explanation (references are a plus) on Python slicing.'},
#  {'summary': 'Finding the index of an item in a list',
#   'votes': '4173',
#   'excerpt': 'Given a list ["foo", "bar", "baz"] and an item in the list "bar", how do I get its index 1?'},
#  {'summary': "Iterating over dictionaries using 'for' loops",
#   'votes': '4029',
#   'excerpt': "d = {'x': 1, 'y': 2, 'z': 3}\n\nfor key in d:\n    print(key, 'corresponds to', d[key])\n\nHow does Python recognize that it needs only to read the key from the dictionary? Is key a special keyword, or is ..."},
#  {'summary': 'Using global variables in a function',
#   'votes': '3767',
#   'excerpt': 'How do I create or use a global variable inside a function?\nHow do I use a global variable that was defined in one function inside other functions?\n\nFailing to use the global keyword where appropriate ...'},
#  {'summary': 'How to iterate over rows in a DataFrame in Pandas',
#   'votes': '3655',
#   'excerpt': 'I have a pandas dataframe, df:\n   c1   c2\n0  10  100\n1  11  110\n2  12  120\n\nHow do I iterate over the rows of this dataframe? For every row, I want to be able to access its elements (values in cells) ...'},
#  {'summary': 'How do I get the current time?',
#   'votes': '3627',
#   'excerpt': 'How do I get the current time?'},
#  {'summary': 'Catch multiple exceptions in one line (except block)',
#   'votes': '3598',
#   'excerpt': 'I know that I can do:\n\ntry:\n    # do something that may fail\nexcept:\n    # do this if ANYTHING goes wrong\nI can also do this:\n\ntry:\n    # do something that may fail\nexcept IDontLikeYouException:\n    #...'},
#  {'summary': "Does Python have a string 'contains' substring method?",
#   'votes': '3588',
#   'excerpt': 'I\'m looking for a string.contains or string.indexof method in Python.\n\nI want to do:\n\nif not somestring.contains("blah"):\n   continue'},
#  {'summary': 'What is the difference between __str__ and __repr__?',
#   'votes': '3495',
#   'excerpt': 'What is the difference between __str__ and __repr__ in Python?'},
#  {'summary': 'Convert bytes to a string',
#   'votes': '3483',
#   'excerpt': "I captured the standard output of an external program into a bytes object:\n>>> from subprocess import *\n>>> command_stdout = Popen(['ls', '-l'], stdout=PIPE).communicate()[0]\n>>..."},
#  {'summary': 'How do I list all files of a directory?',
#   'votes': '3467',
#   'excerpt': 'How can I list all files of a directory in Python and add them to a list?'},
#  {'summary': 'How to copy files?',
#   'votes': '3443',
#   'excerpt': 'How do I copy a file in Python?'},
#  {'summary': 'How do I sort a dictionary by value?',
#   'votes': '3416',
#   'excerpt': 'I have a dictionary of values read from two fields in a database: a string field and a numeric field. The string field is unique, so that is the key of the dictionary.\n\nI can sort on the keys, but how ...'},
#  {'summary': 'How can I add new keys to a dictionary?',
#   'votes': '3384',
#   'excerpt': "How do I add a key to an existing dictionary? It doesn't have an .add() method."},
#  {'summary': 'What is __init__.py for?',
#   'votes': '3382',
#   'excerpt': 'What is __init__.py for in a Python source directory?'},
#  {'summary': 'How do I concatenate two lists in Python?',
#   'votes': '3245',
#   'excerpt': 'How do I concatenate two lists in Python?\n\nExample:\n\nlistone = [1, 2, 3]\nlisttwo = [4, 5, 6]\nExpected outcome:\n\n>>> joinedlist\n[1, 2, 3, 4, 5, 6]'},
#  {'summary': 'How do I check if a list is empty?',
#   'votes': '3230',
#   'excerpt': 'For example, if passed the following:\n\na = []\nHow do I check to see if a is empty?'},
#  {'summary': '"Least Astonishment" and the Mutable Default Argument',
#   'votes': '3230',
#   'excerpt': 'Anyone tinkering with Python long enough has been bitten (or torn to pieces) by the following issue:\ndef foo(a=[]):\n    a.append(5)\n    return a\n\nPython novices would expect this function called with ...'},
#  {'summary': 'How do I select rows from a DataFrame based on column values?',
#   'votes': '3179',
#   'excerpt': 'How can I select rows from a DataFrame based on values in some column in Pandas?\nIn SQL, I would use:\nSELECT *\nFROM table\nWHERE column_name = some_value'},
#  {'summary': 'How do I pass a variable by reference?',
#   'votes': '3157',
#   'excerpt': "Are parameters passed by reference or by value? How do I pass by reference so that the code below outputs 'Changed' instead of 'Original'?\nclass PassByReference:\n    def __init__(self):\n        self...."},
#  {'summary': "How do I clone a list so that it doesn't change unexpectedly after assignment?",
#   'votes': '3150',
#   'excerpt': 'While using new_list = my_list, any modifications to new_list changes my_list every time. Why is this, and how can I clone or copy the list to prevent it?'},
#  {'summary': 'What does ** (double star/asterisk) and * (star/asterisk) do for parameters?',
#   'votes': '3147',
#   'excerpt': 'What do *args and **kwargs mean?\ndef foo(x, y, *args):\ndef bar(x, y, **kwargs):'},
#  {'summary': 'How do I make a time delay? [duplicate]',
#   'votes': '3119',
#   'excerpt': 'How do I put a time delay in a Python script?'},
#  {'summary': "What is the difference between Python's list methods append and extend?",
#   'votes': '3113',
#   'excerpt': "What's the difference between the list methods append() and extend()?"},
#  {'summary': 'Understanding Python super() with __init__() methods [duplicate]',
#   'votes': '3079',
#   'excerpt': 'Why is super() used?\nIs there a difference between using Base.__init__ and super().__init__?\nclass Base(object):\n    def __init__(self):\n        print "Base created"\n        \nclass ChildA(...'},
#  {'summary': 'How do I delete a file or folder in Python?',
#   'votes': '3078',
#   'excerpt': 'How do I delete a file or folder?'},
#  {'summary': 'How do I make function decorators and chain them together?',
#   'votes': '3065',
#   'excerpt': 'How do I make two decorators in Python that would do the following?\n@make_bold\n@make_italic\ndef say():\n   return "Hello"\n\nCalling say() should return:\n"<b><i>Hello</i>&...'},
#  {'summary': 'How do I change the size of figures drawn with Matplotlib?',
#   'votes': '3016',
#   'excerpt': 'How do I change the size of figure drawn with Matplotlib?'},
#  {'summary': 'Manually raising (throwing) an exception in Python',
#   'votes': '2991',
#   'excerpt': 'How do I raise an exception in Python so that it can later be caught via an except block?'},
#  {'summary': 'How do I split a list into equally-sized chunks?',
#   'votes': '2937',
#   'excerpt': 'How do I split a list of arbitrary length into equal sized chunks?\n\nSee How to iterate over a list in chunks if the data result will be used directly for a loop, and does not need to be stored.\nFor ...'},
#  {'summary': 'How do I print colored text to the terminal?',
#   'votes': '2931',
#   'excerpt': 'How do I output colored text to the terminal in Python?'},
#  {'summary': 'How do I access environment variables in Python?',
#   'votes': '2916',
#   'excerpt': 'How do I get the value of an environment variable in Python?'},
#  {'summary': 'Convert string "Jun 1 2005 1:33PM" into datetime',
#   'votes': '2859',
#   'excerpt': 'How do I convert the following string to a datetime object?\n"Jun 1 2005  1:33PM"'},
#  {'summary': "Find the current directory and file's directory [duplicate]",
#   'votes': '2821',
#   'excerpt': 'How do I determine:\n\nthe current directory (where I was in the terminal when I ran the Python script), and\nwhere the Python file I am executing is?'},
#  {'summary': 'Why is "1000000000000000 in range(1000000000000001)" so fast in Python 3?',
#   'votes': '2821',
#   'excerpt': 'It is my understanding that the range() function, which is actually an object type in Python 3, generates its contents on the fly, similar to a generator.\nThis being the case, I would have expected ...'},
#  {'summary': 'Renaming column names in Pandas',
#   'votes': '2709',
#   'excerpt': "I want to change the column labels of a Pandas DataFrame from\n['$a', '$b', '$c', '$d', '$e']\n\nto\n['a', 'b', 'c', 'd', 'e']"},
#  {'summary': 'Check if a given key already exists in a dictionary',
#   'votes': '2679',
#   'excerpt': 'I wanted to test if a key exists in a dictionary before updating the value for the key.\nI wrote the following code:\n\nif \'key1\' in dict.keys():\n  print "blah"\nelse:\n  print "boo"\nI think this is not ...'},
#  {'summary': 'How can I remove a key from a Python dictionary?',
#   'votes': '2669',
#   'excerpt': "Is there a one-line way of deleting a key from a dictionary without raising a KeyError?\nif 'key' in my_dict:\n    del my_dict['key']"},
#  {'summary': 'How do I parse a string to a float or int?',
#   'votes': '2652',
#   'excerpt': 'How can I convert a str to float?\n"545.2222"  →  545.2222\nHow can I convert a str to int?\n"31"        →  31\nFor the reverse, see Convert integer to string in Python and ...'},
#  {'summary': 'How do I get the last element of a list?',
#   'votes': '2633',
#   'excerpt': 'How do I get the last element of a list?'},
#  {'summary': 'How do I sort a list of dictionaries by a value of the dictionary?',
#   'votes': '2594',
#   'excerpt': "How do I sort a list of dictionaries by a specific key's value? Given:\n[{'name': 'Homer', 'age': 39}, {'name': 'Bart', 'age': 10}]\n\nWhen sorted by name, it should become:\n[{'name': 'Bart', 'age': 10}, ..."},
#  {'summary': 'How to upgrade all Python packages with pip?',
#   'votes': '2587',
#   'excerpt': 'Is it possible to upgrade all Python packages at one time with pip?\nNote: that there is a feature request for this on the official issue tracker.'},
#  {'summary': 'How do I get a substring of a string in Python?',
#   'votes': '2564',
#   'excerpt': "I want to get a new string from the third character to the end of the string, e.g. myString[2:end]. If omitting the second part means 'till the end', and if you omit the first part, does it start from ..."},
#  {'summary': 'How do I lowercase a string in Python?',
#   'votes': '2463',
#   'excerpt': 'Is there a way to convert a string to lowercase?\n"Kilometers"  →  "kilometers"'},
#  {'summary': 'Static class variables and methods in Python',
#   'votes': '2424',
#   'excerpt': 'How do I create static class variables or methods in Python?'},
#  {'summary': 'How to print without a newline or space',
#   'votes': '2317',
#   'excerpt': 'Example in C:\nfor (int i = 0; i < 4; i++)\n    printf(".");\n\nOutput:\n....\n\nIn Python:\n>>> for i in range(4): print(\'.\')\n.\n.\n.\n.\n>>> print(\'.\', \'.\', \'.\', \'.\')\n. . . .\n\nIn ...'},
#  {'summary': 'Calling a function of a module by using its name (a string)',
#   'votes': '2292',
#   'excerpt': 'How do I call a function, using a string with the function\'s name? For example:\nimport foo\nfunc_name = "bar"\ncall(foo, func_name)  # calls foo.bar()'},
#  {'summary': 'How to leave/exit/deactivate a Python virtualenv',
#   'votes': '2281',
#   'excerpt': "I'm using virtualenv and the virtualenvwrapper. I can switch between virtualenv's just fine using the workon command.\nme@mymachine:~$ workon env1\n(env1)me@mymachine:~$ workon env2\n(env2)me@mymachine:~$..."},
#  {'summary': 'How do I determine if an object has an attribute in Python?',
#   'votes': '2266',
#   'excerpt': 'How do I determine if an object has some attribute? For example:\n>>> a = SomeClass()\n>>> a.property\nTraceback (most recent call last):\n  File "<stdin>", line 1, in &...'},
#  {'summary': 'Importing files from different folder',
#   'votes': '2257',
#   'excerpt': 'I have this folder structure:\napplication\n├── app\n│\xa0\xa0 └── folder\n│\xa0\xa0     └── file.py\n└── app2\n    └── some_folder\n        └── some_file.py\n\nHow can I import a function from file.py, from within ...'},
#  {'summary': 'How can I randomly select an item from a list?',
#   'votes': '2245',
#   'excerpt': "How do I retrieve an item at random from the following list?\nfoo = ['a', 'b', 'c', 'd', 'e']"},
#  {'summary': 'How do I print curly-brace characters in a string while using .format?',
#   'votes': '2209',
#   'excerpt': 'Non-working example:\nprint(" \\{ Hello \\} {0} ".format(42))\n\nDesired output:\n {Hello} 42'},
#  {'summary': 'How do I get the number of elements in a list (length of a list) in Python?',
#   'votes': '2208',
#   'excerpt': 'How do I get the number of elements in the list items?\nitems = ["apple", "orange", "banana"]\n\n# There are 3 items.'},
#  {'summary': 'Limiting floats to two decimal points',
#   'votes': '2200',
#   'excerpt': 'I want a to be rounded to 13.95. I tried using round, but I get:\n>>> a\n13.949999999999999\n>>> round(a, 2)\n13.949999999999999\nFor the analogous issue with the standard library ...'},
#  {'summary': 'Why is reading lines from stdin much slower in C++ than Python?',
#   'votes': '2116',
#   'excerpt': 'I wanted to compare reading lines of string input from stdin using Python and C++ and was shocked to see my C++ code run an order of magnitude slower than the equivalent Python code. Since my C++ is ...'},
#  {'summary': 'How to remove an element from a list by index',
#   'votes': '2091',
#   'excerpt': 'How do I remove an element from a list by index?\nI found list.remove(), but this slowly scans the list for an item by value.'},
#  {'summary': 'Is there a way to run Python on Android?',
#   'votes': '2085',
#   'excerpt': 'We are working on an S60 version and this platform has a nice Python API..\n\nHowever, there is nothing official about Python on Android, but since Jython exists, is there a way to let the snake and the ...'},
#  {'summary': 'Determine the type of an object? [duplicate]',
#   'votes': '2069',
#   'excerpt': 'Is there a simple way to determine if a variable is a list, dictionary, or something else?'},
#  {'summary': "How to determine a Python variable's type?",
#   'votes': '2058',
#   'excerpt': 'How do I see the type of a variable? (e.g. unsigned 32 bit)'},
#  {'summary': 'How do I count the occurrences of a list item?',
#   'votes': '2043',
#   'excerpt': 'Given a single item, how do I count occurrences of it in a list, in Python?\n\nA related but different problem is counting occurrences of each different element in a collection, getting a dictionary or ...'},
#  {'summary': 'Delete an element from a dictionary',
#   'votes': '2026',
#   'excerpt': 'How do I delete an item from a dictionary in Python?\nWithout modifying the original dictionary, how do I obtain another dict with the item removed?'},
#  {'summary': 'How to read a file line-by-line into a list?',
#   'votes': '2025',
#   'excerpt': 'How do I read every line of a file in Python and store each line as an element in a list? \n\nI want to read the file line by line and append each line to the end of the list.'},
#  {'summary': 'Why is it string.join(list) instead of list.join(string)?',
#   'votes': '2017',
#   'excerpt': 'This has always confused me. It seems like this would be nicer:\n["Hello", "world"].join("-")\n\nThan this:\n"-".join(["Hello", "world"])\n\nIs ...'},
#  {'summary': 'Delete a column from a Pandas DataFrame',
#   'votes': '2016',
#   'excerpt': "To delete a column in a DataFrame, I can successfully use:\ndel df['column_name']\n\nBut why can't I use the following?\ndel df.column_name\n\nSince it is possible to access the column/Series as df...."}]

# %%
browser.quit()
