# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 107.0.5304
# [WDM] - Get LATEST driver version for 107.0.5304
# [WDM] - Driver [C:\Users\19198\.wdm\drivers\chromedriver\win32\107.0.5304.62\chromedriver.exe] found in cache

# %%
url = "https://globalvoices.org/page/2/"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Close the dialogue box
browser.links.find_by_partial_text("No thanks").click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-3-936c1335a738> in <module>
#       1 # Close the dialogue box
# ----> 2 browser.links.find_by_partial_text("No thanks").click()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     817                 error = e
#     818
# --> 819         raise error
#     820
#     821     def check(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     810         while time.time() < end_time:
#     811             try:
# --> 812                 return self._element.click()
#     813             except(
#     814                 ElementClickInterceptedException,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=107.0.5304.88)

# %%
# List to contain article info
articles_list = []

# %%
def get_summary():
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    
    main_area = soup.find("div", class_="post-archive-container")
    articles = main_area.find_all("div", class_="gv-promo-card-text")
    
    for article in articles:
        header = article.find("h3", class_="post-title").text.strip()
        date = article.find("span", class_="datestamp")["title"]
        date = date.replace('_', '')
        
        
        summary_dict = {
            "header": header,
            "date": date
        }
        articles_list.append(summary_dict)

# %%
for _ in range(5):
    get_summary()
    browser.links.find_by_partial_text("Older").click()

# %%
articles_list
# Out:
# [{'header': 'Giant cats on walls: Odesa street art inspired by the war, but not only',
#   'date': '26 10 2022'},
#  {'header': 'Armenia is rocked by the suicide of a gay couple',
#   'date': '26 10 2022'},
#  {'header': 'Explaining the 20th Congress of the Communist Party of China: Struggle and fight',
#   'date': '26 10 2022'},
#  {'header': '‘A girl with a Hindu heart’', 'date': '25 10 2022'},
#  {'header': 'Police detains scores of activists at an opposition party rally in Azerbaijan',
#   'date': '25 10 2022'},
#  {'header': 'Klinika Bernardo pioneers, innovates community health care for HIV patients in the Philippines',
#   'date': '25 10 2022'},
#  {'header': 'One of the last Ladino language speakers in Bosnia, Moris Albahari, passed away',
#   'date': '25 10 2022'},
#  {'header': 'In Trinidad & Tobago, Divali remains a festival beloved by people of all faiths',
#   'date': '24 10 2022'},
#  {'header': 'How Palestinian youth resisted Israeli occupation: With a haircut',
#   'date': '24 10 2022'},
#  {'header': 'Activists predict homophobic and transphobic violence in Russia, but most avenues of escape are slammed shut',
#   'date': '24 10 2022'},
#  {'header': "‘Call them by their names': Stories of Russian anti-war political prisoners",
#   'date': '24 10 2022'},
#  {'header': 'How the hot chilli pepper ‘Akabare’ came to tickle the taste-buds of Nepali noodle lovers',
#   'date': '24 10 2022'},
#  {'header': 'More guns, fewer control mechanisms: Brazilian journalist analyzes Bolsonaro’s gun policy',
#   'date': '23 10 2022'},
#  {'header': 'Brazilian candidates reduce attention on peripheral neighborhoods in 2022 elections',
#   'date': '22 10 2022'},
#  {'header': 'Explaining the 20th Congress of the Communist Party of China: Jiangshan',
#   'date': '21 10 2022'},
#  {'header': "Australia's unique natural wonders are at risk from ecotourism expansion",
#   'date': '21 10 2022'},
#  {'header': "The love and hate relationship of Hungary's ruling party Fidesz and Facebook",
#   'date': '21 10 2022'},
#  {'header': 'Turkish lawmakers ratify new disinformation bill',
#   'date': '21 10 2022'},
#  {'header': 'Ola Bini, the cyberactivist who causes panic in Ecuador',
#   'date': '21 10 2022'},
#  {'header': 'Filming Gyani Maiya Sen who inspired efforts to revive the dying Kusunda language in Nepal',
#   'date': '20 10 2022'},
#  {'header': 'In Ukraine, the war has reshaped language to create new idioms',
#   'date': '20 10 2022'},
#  {'header': "From ‘forerunner’ to ‘a puppy': How Mongolia got hooked on Russia's ‘Pivot to Asia’",
#   'date': '20 10 2022'},
#  {'header': 'Citizen journalists face challenges in Cambodia, Thailand, and Myanmar',
#   'date': '19 10 2022'},
#  {'header': 'Ugandan poet spreads her message despite new law to criminalize online dissent',
#   'date': '19 10 2022'},
#  {'header': "‘The fight for human rights begins in the kitchen': Interview with Czech writer Radka Denemarková",
#   'date': '19 10 2022'},
#  {'header': 'Can Jamaica efficiently make the much-needed transition to renewable energy?',
#   'date': '18 10 2022'},
#  {'header': 'The struggle to maintain an independent russophone voice in Moldova',
#   'date': '18 10 2022'},
#  {'header': 'Kianoush Ramezani: The journey of an exiled political cartoonist',
#   'date': '17 10 2022'},
#  {'header': 'Russian social media users now also want to say no to war while not actually saying it',
#   'date': '17 10 2022'},
#  {'header': "Murder of two queer people by far-right teen signals worsening plight of Slovakia's LGBTQ+ community",
#   'date': '17 10 2022'},
#  {'header': 'The sudden passing of Haitian singer ‘Mikaben’ leaves a big void in the music world',
#   'date': '17 10 2022'},
#  {'header': "Will banning music glorifying violence from the airwaves reduce Jamaica's crime rate?",
#   'date': '16 10 2022'},
#  {'header': 'Nong Bua Lamphu massacre in Thailand: Recounting mistakes, seeking a way forward',
#   'date': '16 10 2022'},
#  {'header': "Albania's tourism industry is on the rise, increasing risk of child sexual exploitation, warns new report",
#   'date': '16 10 2022'},
#  {'header': 'China censors online chatter after anti-Xi Jinping protest; Hong Kong media muted',
#   'date': '15 10 2022'},
#  {'header': 'In the face of stubborn adherence to outdated dress codes, one Trinidadian citizen gets creative',
#   'date': '14 10 2022'},
#  {'header': 'The true colours of Truecaller in India: app accused of being negligent about data privacy',
#   'date': '14 10 2022'},
#  {'header': 'Ukrainians and Russians turn to Twitter memes about Elon Musk, but this time the tone is no longer humorous',
#   'date': '14 10 2022'},
#  {'header': 'Activists decry shrinking freedom of expression in the Philippines',
#   'date': '14 10 2022'},
#  {'header': 'Digitization of public services in Albania has increased their quality, digital rights analyst claims',
#   'date': '14 10 2022'},
#  {'header': 'Photographer Aleksandr Yakimchuk recreates Odesa in black-and-white',
#   'date': '14 10 2022'},
#  {'header': 'Can music and feminism help heal border conflicts in Central Asia?',
#   'date': '14 10 2022'},
#  {'header': 'The world must hear the voice of Iranian women',
#   'date': '13 10 2022'},
#  {'header': 'The Civic Media Observatory: Making sense of people’s speech, memes, and tweets',
#   'date': '13 10 2022'},
#  {'header': 'Water scarcity in Indigenous communities should be reported on, a young Bolivian journalist says',
#   'date': '13 10 2022'},
#  {'header': "“We also speak Russian in Moldova, but don't want to have anything to do with the so-called Russian World”, says Moldovan writer Iulian Ciocan",
#   'date': '13 10 2022'},
#  {'header': "Activists speculate on Elon Musk's foreign influence after proposing Ukraine and Taiwan peace deals",
#   'date': '13 10 2022'},
#  {'header': 'The death of 69 Gambian children from Indian-made cough syrups sparks public outrage',
#   'date': '11 10 2022'},
#  {'header': 'Can citizens of democracies still trust the law? A Global Voices Insights discussion',
#   'date': '11 10 2022'},
#  {'header': 'Iranian protest crackdown targets ethnic minorities',
#   'date': '10 10 2022'},
#  {'header': "Armenia and Azerbaijan recognize each other's territorial integrity",
#   'date': '10 10 2022'},
#  {'header': "‘When the porridge is hot, one eats it on the side': Haiti's current protests, explained on Twitter",
#   'date': '9 10 2022'},
#  {'header': "‘Explainer,’ Trinidad & Tobago's ‘calypso messenger,’ passes on",
#   'date': '8 10 2022'},
#  {'header': "Why most Salvadorans want Bukele's re-election despite his growing authoritarianism",
#   'date': '7 10 2022'},
#  {'header': "Of coal pots, bicycles and macaroni pie: Is Trinidad & Tobago's government out of touch?",
#   'date': '7 10 2022'},
#  {'header': 'Indian farmers are pushed to despair with huge bank loans',
#   'date': '7 10 2022'},
#  {'header': 'Russians fleeing Putin’s war face long border queues, overpriced flights, fear, and uncertainty',
#   'date': '7 10 2022'},
#  {'header': 'Is the ‘water machine of Bengal’ preventing more flood disasters in Bangladesh?',
#   'date': '7 10 2022'},
#  {'header': 'Civil society groups call for justice after a radio broadcaster is killed in the Philippines',
#   'date': '7 10 2022'},
#  {'header': "Twiplomacy:\xa0Uganda's General Muhoozi's tweets threaten peace in East African Region",
#   'date': '7 10 2022'},
#  {'header': 'Blood and democracy: the fight for animal rights in Azerbaijan',
#   'date': '7 10 2022'},
#  {'header': 'Twitter Space: The Ukrainian language and its global significance',
#   'date': '6 10 2022'},
#  {'header': 'Schools close as lingering weather system continues to affect Trinidad & Tobago',
#   'date': '6 10 2022'},
#  {'header': 'Trinidad & Tobago suffers the effects of yet another tropical weather system',
#   'date': '6 10 2022'},
#  {'header': 'Unfreedom Monitor report: Data Governance', 'date': '6 10 2022'},
#  {'header': 'Hong Kong’s wealth gap reaches ‘tipping point’ under COVID as unemployment rises among poor',
#   'date': '6 10 2022'},
#  {'header': 'Why are so many teachers giving up their careers in Hong Kong?',
#   'date': '6 10 2022'},
#  {'header': 'Brazil’s first round of elections: left scores historical wins but bolsonarism still strong',
#   'date': '5 10 2022'},
#  {'header': 'Women in Turkey stand in solidarity with women of Iran',
#   'date': '4 10 2022'},
#  {'header': 'Supporters hold rallies around the world in solidarity with the Iranian people',
#   'date': '4 10 2022'},
#  {'header': 'A young chef in Baku turns his flat into a restaurant',
#   'date': '4 10 2022'},
#  {'header': 'Cubans initiate new wave of protests over blackouts and hunger',
#   'date': '4 10 2022'},
#  {'header': "In Brazil's election year, women in politics denounce recurring threats",
#   'date': '3 10 2022'},
#  {'header': 'Portugal apologizes for colonial massacre in Mozambique',
#   'date': '3 10 2022'},
#  {'header': 'Angola’s elections: the incumbent MPLA wins, but the opposition disputes results',
#   'date': '3 10 2022'},
#  {'header': "Catholics and evangelicals may get to decide Brazil's next president",
#   'date': '2 10 2022'},
#  {'header': 'Under Bolsonaro, political attacks gain institutional legitimacy in Brazil',
#   'date': '2 10 2022'},
#  {'header': 'The great escape from Russia: Live on Russian Twitter',
#   'date': '30 09 2022'},
#  {'header': 'Filipino writers and academics push back against book censorship',
#   'date': '30 09 2022'},
#  {'header': 'Papua New Guinea’s new media rules could undermine the work of journalists',
#   'date': '30 09 2022'},
#  {'header': "Why fear of a coup attempt is on the horizon in Brazil's elections",
#   'date': '29 09 2022'},
#  {'header': 'Brazil’s courts debate use of billboards in political campaigns',
#   'date': '29 09 2022'},
#  {'header': 'Unfreedom Monitor report: Morocco', 'date': '29 09 2022'},
#  {'header': 'Undertones: Anti-army hashtags gain rare visibility in Pakistan',
#   'date': '29 09 2022'},
#  {'header': "‘The Art of the Steal?': Russia’s online voting problem",
#   'date': '29 09 2022'},
#  {'header': 'A Georgian neo-Nazi group finds a home on YouTube',
#   'date': '29 09 2022'},
#  {'header': "Nepal's Citizenship Bill attracts renewed controversy",
#   'date': '29 09 2022'},
#  {'header': "Iran's most recent protests are unprecedented — here is why",
#   'date': '28 09 2022'},
#  {'header': 'Croatia’s push for controversial electoral reform undermines democratic development of Bosnia and Herzegovina',
#   'date': '27 09 2022'},
#  {'header': 'Turkish citizens feel the squeeze of increased EU visa rejections',
#   'date': '27 09 2022'},
#  {'header': '‘Where’s the President?’ trends as super typhoon batters the Philippines',
#   'date': '27 09 2022'},
#  {'header': 'The Nicaraguan government looks to imprison Catholic priests and stain their image',
#   'date': '26 09 2022'},
#  {'header': 'Hong Kong attempts to reconnect with the world by relaxing COVID-19 travel restrictions',
#   'date': '26 09 2022'},
#  {'header': 'My journey to learning Ukrainian and the online language tools that took me there',
#   'date': '26 09 2022'},
#  {'header': 'The Greek spyware scandal: When technology outpaces governance',
#   'date': '26 09 2022'},
#  {'header': 'Far from home, alone: Cambodian students share life in Thailand during the pandemic lockdown',
#   'date': '25 09 2022'},
#  {'header': 'Hong Kong press freedom index sinks to new low as media outlets disappear',
#   'date': '25 09 2022'},
#  {'header': 'Cosplay: the pop-culture phenomenon comes back to Kathmandu',
#   'date': '23 09 2022'},
#  {'header': '‘We are poorer without her’: Trinbagonian human rights advocate Hazel Brown dies',
#   'date': '23 09 2022'},
#  {'header': 'Protests erupt in Iran over the death of Mahsa Amini',
#   'date': '23 09 2022'},
#  {'header': 'The wolf is being targeted and killed in North Macedonia',
#   'date': '23 09 2022'},
#  {'header': 'Unfreedom Monitor Report: Egypt', 'date': '23 09 2022'},
#  {'header': 'Bolsonaro celebrates Brazil’s independence with a dead emperor’s heart and the armed forces',
#   'date': '22 09 2022'},
#  {'header': 'Looking at the GotaGoGama protests as a learning curve for Sri Lanka',
#   'date': '22 09 2022'},
#  {'header': 'Protests mark 50th anniversary of Martial Law declaration in the Philippines',
#   'date': '22 09 2022'}]

# %%
import pandas as pd
df = pd.DataFrame(articles_list)
df.head()
# Out:
#                                               header        date
# 0  Giant cats on walls: Odesa street art inspired...  26 10 2022
# 1   Armenia is rocked by the suicide of a gay couple  26 10 2022
# 2  Explaining the 20th Congress of the Communist ...  26 10 2022
# 3                        ‘A girl with a Hindu heart’  25 10 2022
# 4  Police detains scores of activists at an oppos...  25 10 2022

# %%
df.date = pd.to_datetime(df.date)
# Out:
# <ipython-input-9-d0698d50b207>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df.date = pd.to_datetime(df.date)

# %%
df
# Out:
#                                                 header       date
# 0    Giant cats on walls: Odesa street art inspired... 2022-10-26
# 1     Armenia is rocked by the suicide of a gay couple 2022-10-26
# 2    Explaining the 20th Congress of the Communist ... 2022-10-26
# 3                          ‘A girl with a Hindu heart’ 2022-10-25
# 4    Police detains scores of activists at an oppos... 2022-10-25
# ..                                                 ...        ...
# 100  The wolf is being targeted and killed in North... 2022-09-23
# 101                    Unfreedom Monitor Report: Egypt 2022-09-23
# 102  Bolsonaro celebrates Brazil’s independence wit... 2022-09-22
# 103  Looking at the GotaGoGama protests as a learni... 2022-09-22
# 104  Protests mark 50th anniversary of Martial Law ... 2022-09-22
#
# [105 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   header  105 non-null    object
#  1   date    105 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.8+ KB

# %%
browser.quit()
