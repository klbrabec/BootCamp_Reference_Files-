# %% [markdown]
# Week 6 Module Notes
#
# Gathering data from an API is more efficient
# Allows you to request data from a database or webserver
# Java Script Object Notation - JSON -
# Stores multiple types of data
#
# Downloaded and installed files - they are here: C:\Users\kbrabec\Documents\Coursework\Python Unit\Wk 4\Wk 6
#
# It's always a good idea to know/understand the data that you are working with in order to make good decisions and design logic correctly
#
# Random numberes can be generated using the Python Random module.

# %%
#import the random function 
import random

# %%
random.random()
# Out:
# 0.8687104768021772

# %% [markdown]
# random() generates a single floating point decimal between 0 and 1
# You can combine random.random() and random.randint() to generate the values that you need for latitude values.

# %%
random.randint(-90, 90)
# Out:
# 39

# %% [markdown]
# Randint()
# Short for random integer
# random.randint(-90.90)
# This will return a single integer between -90 and 90

# %%
random_number = random.randint(-90, 89)+random.random()
random_number
# Out:
# -71.79654128340674

# %% [markdown]
# The code below can be used to generate a ten random floating point decimals between -90 and 89

# %%
x=1 #assign variable X to 1 
latitudes =[] #initialize an empty list 
while x < 11: #loop to generate random latitudes and add to list 
    random_lat = random.randint(-90, 89) + random.random() 
    latitudes.append (random_lat)
    x += 1 #increment x 
    
latitudes #show list after loop completes
# Out:
# [54.98396894772897,
#  -5.982213685387993,
#  -81.33238680152624,
#  10.972665891467289,
#  64.44907476073958,
#  -34.62171049829708,
#  -61.08431967174432,
#  72.57766437932666,
#  -27.429168368110158,
#  88.93440064916507]

# %% [markdown]
# randrange() - sets the range for random numbers to be pulled from.
# also includes a step parameter - generates increments of the given integer value
# ex - random.randrange(-90, 90, step=1)

# %%
random.randrange(-90, 90, step=1)
# Out:
# 75

# %%
random.randrange(-90, 90, step=3)
# Out:
# -54

# %% [markdown]
# If you don't add the step paraemeter, the output will be a number with an increment of 1 (default integer value)
#
# uniform() - allows us to generate a floating point decimal number between numbers defined inside the parentheses

# %%
random.uniform (-90, 90)
# Out:
# -74.07976036547468

# %% [markdown]
# randint(-90,89) - returns an integer between the defined interval. This will _NOT_ generate a flaoting point decimal number
#
# random() - returns a floating point decimal number between 0 and 1 - will not generate a whole integer
#
# randrange(-90,90, step=1) returns a whole integer between the interval (-90 and 90 where the step is the difference between each number in the sequence.  This will not generate a floating-point decimal number.
#
# uniform (-90,90) - returns a floating point decimal number between the defined interval.  This will not generate a whole number.
#
# To generate large numbers of lat/long - you can combine NumPy with Random (NumPy has a built it random module and supplements the built in python random module)

# %%
#Import the NumPy module 
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -12.230560764992262

# %%
np.random.uniform(low = -90, high = 90, size = 50)
# Out:
# array([ 75.16168546,  58.17839289, -51.72601932,  55.27452638,
#        -46.90713604, -60.46395781, -25.26817019, -72.45421974,
#        -41.7734344 ,  68.62365249,  -6.36869896, -76.18589289,
#        -51.78693644, -84.31352368,  14.98857273, -19.75376439,
#        -44.13120882, -36.56169123,  70.5509349 ,  42.00992412,
#         -1.58438522,  23.24256818, -89.93272983, -73.47720861,
#         18.65257992, -57.70017548, -81.32312139, -31.13013955,
#         38.64601364, -74.42410588,  42.45987734, -72.79920724,
#        -71.28055489,  64.18737522, -54.31565086, -23.96524258,
#         -2.04242567,  16.34635964, -21.14713409,  73.77292945,
#        -73.61745111, -86.87180437, -64.10368287,  19.4547828 ,
#        -42.18557196, -44.76024564,   7.33101527, -81.84901478,
#        -33.14894272,  31.02043186])

# %% [markdown]
# The above method is faster than looping through a while loop.
# Can use the timeit module to test this theory.

# %%
#import timeit
import timeit

# %%
# %timeit 
np.random.uniform(-90.000, 90.000, size = 1500)
# Out:
# array([-76.39114217,  22.04326399,  52.68870674, ..., -10.4835584 ,
#         18.73082139, -31.2110547 ])

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.91 ms ± 25 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
#skill drill - refactor the code for the while loop with the #timeit magic command and write a for loop that will generate the 1500 lats 

x=1 #assign variable X to 1 
latitudes =[] #initialize an empty list 
while x < 1501: #loop to generate random latitudes and add to list 
    random_lat = random.randint(-90, 89) + random.random() 
    latitudes.append (random_lat)
    x += 1 #increment x 
    
# %timeit latitudes #show list after loop completes
# Out:
# 28.6 ns ± 1.62 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# Create Latitude and Longitude Combinations

# %%
#import dependencies 

import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# zip() packs each pair of lats/lngs having the same index in their array into a tuple. (This creates 1500 lats/long tuples)
#
# Practice/sample below

# %%
# Create a practice set of random latitude and longitude combinations.
lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# You can only unzip a zipped tuple once - This then removes it from the computer's memory.

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 29.326160683352114 -20.34170420609064
# -87.51992093827592 72.8671031600291
# 26.323941827428754 94.23583331329979
# -19.985814168723763 62.02460612325373
# -78.68162509182089 54.531656102158564
# 76.54801411257469 177.00974471205927
# -73.74396254018515 -120.4663378339118
# 8.010236916016382 -16.33104636193923
# -39.544815847598265 -38.78323615571813
# -85.61886902676727 -155.00428665656645
# -2.046627107276038 129.07830961767866
# 68.78037908715984 -125.1239140887985
# -19.987412691439047 -125.20504688686114
# -9.571649818966605 71.04454076571665
# -73.69922521092126 -119.49202370939636
# -5.481888783160102 -153.5905841542589
# 23.746197128715337 103.65148691439208
# -85.95232128390617 -9.694109262352157
# 19.89097760110336 30.85519750867715
# -54.214950025932275 109.42389597708654
# -87.52796607919666 12.388175047704152
# 38.96925601008914 -137.48279315309554
# -67.42067299739512 109.84780397807663
# 66.05330305398829 31.898367422066315
# 21.09522498021471 58.85076971438363
# ...

# %%
#pip install citipy
#this will install the citipy module 

#link to citipy documentation https://github.com/wingchen/citipy

# import sys
# !{sys.executable} -m pip install citipy

# %%
from citipy import citipy #imports the citipy script from the citipy module 

city = citipy.nearest_city(22.99, 120.21) 
city 

city.city_name

city.country_code
# Out:
# 'tw'

# %% [markdown]
# When a file containing a scrpt is imported to use in another script, the .py extension does not need to be added to the name of the file when using the import statement.

# %%
#use the citypy module to determine city based on lat/long 

from citipy import citipy

# %%
# Use the print() function to display the latitude and longitude combinations. (These were defined above)
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# los llanos de aridane es
# taolanaro mg
# wokha in
# grand river south east mu
# east london za
# leningradskiy ru
# rikitea pf
# conakry gn
# cidreira br
# mataura pf
# amahai id
# norman wells ca
# rikitea pf
# hithadhoo mv
# punta arenas cl
# faanui pf
# kaiyuan cn
# hermanus za
# marawi sd
# albany au
# bredasdorp za
# fortuna us
# albany au
# pyaozerskiy ru
# sur om
# grafton us
# bambous virieux mu
# butaritari ki
# cape town za
# east london za
# tsnori ge
# funadhoo mv
# zhuhai cn
# rikitea pf
# rikitea pf
# tasiilaq gl
# palabuhanratu id
# asfi ma
# busselton au
# san patricio mx
# barrow us
# half moon bay us
# madimba tz
# taga ws
# kaitangata nz
# mar del plata ar
# okandja ga
# aguimes es
# mataura pf
# port elizabeth za
# kalispell us
# butaritari ki
# tasiilaq gl
# punta arenas cl
# butaritari ki
# san quintin mx
# ribeira grande pt
# basugaon in
# paamiut gl
# jamestown sh
# kapaa us
# ancud cl
# mar del plata ar
# ushuaia ar
# puerto ayora ec
# carnarvon au
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 587

# %% [markdown]
# Notes on the above
# Create a city list to store city names
# iterate through the coordinates list - retrieve the nearest city using lat/long
# if the city is NOT in the cities list, use the append function to add it. (this prevents capturing duplicate cities)
#
# citipy module - finds the nearest city to the lat/long pair with a population of 500 or more.
#
# you should get slightly more than 500 cities - if you get fewer than 500, increase the size limit on the np.random.uniform() function to increase what's returned.

# %% [markdown]
# 6.2.1 - Understanding APIs
#
# APUI call is similar to navigating to a website - it points to a URL and collects data from the webpage or server.
#
# API use has limitations - not all information from a server is accessible.
# APIs may have tiered services - the tier dictates what information is available.
#
# when retrieving data from a website - you have to make a request, returns the data in a text format.
#
# one format to use to parse data is JSON (JavaScript Object Notation)
# Opens and closes with curly braces -
#     Contains a collection of dictionaries and arrays
#
# To request JSON data over the internet - we use the requests library in Python

# %%
import requests 
requests.__version__
# Out:
# '2.27.1'

# %% [markdown]
# Looks like things are not installing into the PythonData2 environment correctly, recommend relying on the Python 3 (ipykernel) environment for all work.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %% [markdown]
# If you get a ModuleNotFoundError message, then either your config.py file is not in the same folder as the Jupyter Notebook file, or the name of your config.py file is not the same in the import statement.
#
# If you get a ImportError message, then the variable for your API key in the code statement is not the same as the variable in your config.py file.
#
# API Documentation - https://requests.kennethreitz.org/en/latest/

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4e5e8fa1e58cb5eb39ce18dd179ebec1

# %% [markdown]
# The site allows you to define units of measurement returned from the API
# https://openweathermap.org/current#data

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4e5e8fa1e58cb5eb39ce18dd179ebec1&q=Boston

# %% [markdown]
# 6.2.4 - Make a request for data to an API
# Always a good idea to review API documentation to ensure that you are interpreting data correctly.
#
# get() - retrieves data from a web source
# head () - retrieves the headers from a web source
# post() - adds or annotates data on a web source - used on mailing groups, message boards or comments
# put () - updates an existing resource
# delete() deletes data from a web source
# options () - discovers what HTTP methods a web source allows
# patch() - partially modifies a web source

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %% [markdown]
# 200 indicates a valid response - you won't see this code when a site appears in a browser, however when a site does not appear, you'll see a 404 code, incidcating a client error

# %%
# Create an endpoint URL for a city. (intentionally misspelled for example)
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city. (correctly spelled)
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %% [markdown]
# valid responses can be sent in various data formats
# - Text
# - JSON
# - XML
# - HTML

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":63.16,"feels_like":62.28,"temp_min":60.62,"temp_max":66.07,"pressure":1009,"humidity":66},"visibility":10000,"wind":{"speed":11.5,"deg":220},"clouds":{"all":75},"dt":1664118317,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1664102083,"sunset":1664145425},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# pulls the JSON text from the 'Get' request 
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 63.16,
#   'feels_like': 62.28,
#   'temp_min': 60.62,
#   'temp_max': 66.07,
#   'pressure': 1009,
#   'humidity': 66},
#  'visibility': 10000,
#  'wind': {'speed': 11.5, 'deg': 220},
#  'clouds': {'all': 75},
#  'dt': 1664118317,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1664102083,
#   'sunset': 1664145425},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# Error handling -
#     when we submit a get request - we want to make sure we get a valid response before we retrieve any data.
#     Can write a conditional expression that will evaluate whether the status code is 200 or not.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %% [markdown]
# if the status_code is something other than 200, JSON data will be returned in the request.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"{city_weather.status_code} City weather not found.")
# Out:
# 404 City weather not found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4e5e8fa1e58cb5eb39ce18dd179ebec1&q=Bston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 63.16,
#   'feels_like': 62.28,
#   'temp_min': 60.62,
#   'temp_max': 66.07,
#   'pressure': 1009,
#   'humidity': 66},
#  'visibility': 10000,
#  'wind': {'speed': 11.5, 'deg': 220},
#  'clouds': {'all': 75},
#  'dt': 1664118317,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1664102083,
#   'sunset': 1664145425},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
#get the JSON data 
boston_data = city_weather.json()

# %%
boston_data["sys"] #sunrise and sunset are the time of day in seconds in a database timestamp format
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1664102083,
#  'sunset': 1664145425}

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1664118317

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
#remember the results here will not match the class examples because they are based on current date/time
# Out:
# 42.3584 -71.0598 66.07 66 75 11.5

# %% [markdown]
# #convert datetimestamp
# #time is stored in coordinated universal time (UTC) or Greenwich Mean time (GMT)
# Can be converted using the datetime module

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 9, 25, 15, 5, 17)

# %%
#convert into a readable format
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-09-25 15:05:17'

# %% [markdown]
# Info about datetime
# https://docs.python.org/3.7/library/datetime.html
#
# https://docs.python.org/3.7/library/datetime.html#strftime-and-strptime-behavior

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print(f"[city] City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | los llanos de aridane
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | wokha
# Processing Record 4 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | leningradskiy
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | conakry
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | amahai
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | faanui
# Processing Record 16 of Set 1 | kaiyuan
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | marawi
# Processing Record 19 of Set 1 | albany
# ...

# %%
a = len(city_data)

a
# Out:
# 541

# %% [markdown]
# Try/except blocks
#     Can be used to prevent API request from stopping prematurely if the request isnt valid.
#     Similar in syntax and structure as the if else statement
#
#     try:
#         Do something
#     except:
#         print (something)
#
# generally not best practice to add the pass statement to the except block - ideally we want to handle each error as it happens and do something specific.
#
# More information on errors and exceptions
# https://docs.python.org/3.7/tutorial/errors.html

# %%
6.2.7 - Create a dataFrame of City Weather Data 

you can convert a list of dictionaries to a dataframe using df-pd.DataFame(list with dictionaries)


to reorder the columns, we assign a variable to an array of the columns in the order we want them to appear:

new_column_order = ["column2", "column4", "column1"]

Then, we assign a new or the same DataFrame with new column order:

df = df[new_column_order]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Los Llanos De Aridane  28.6585  -17.9182     71.13        99         100
# 1                  Wokha  26.1000   94.2667     60.13       100         100
# 2            East London -33.0153   27.9116     67.14        82           0
# 3          Leningradskiy  69.3833  178.4167     30.96        93         100
# 4                Rikitea -23.1203 -134.9692     67.59        63          12
# 5                Conakry   9.5380  -13.6773     80.67        78          75
# 6               Cidreira -30.1811  -50.2056     64.27        72          90
# 7                Mataura -46.1927  168.8643     49.48        97         100
# 8                 Amahai  -3.3333  128.9167     78.22        83          95
# 9           Norman Wells  65.2820 -126.8329     23.04        93          40
#
#    Wind Speed Country                 Date
# 0       10.36      ES  2022-09-25 15:14:12
# 1        0.56      IN  2022-09-25 15:14:12
# ...

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_weather_data= city_data_df[new_column_order]
city_weather_data.head()
# Out:
#                     City Country                 Date      Lat       Lng  \
# 0  Los Llanos De Aridane      ES  2022-09-25 15:14:12  28.6585  -17.9182
# 1                  Wokha      IN  2022-09-25 15:14:12  26.1000   94.2667
# 2            East London      ZA  2022-09-25 15:14:13 -33.0153   27.9116
# 3          Leningradskiy      RU  2022-09-25 15:14:13  69.3833  178.4167
# 4                Rikitea      PF  2022-09-25 15:14:14 -23.1203 -134.9692
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     71.13        99         100       10.36
# 1     60.13       100         100        0.56
# 2     67.14        82           0       21.85
# 3     30.96        93         100        6.11
# 4     67.59        63          12       20.00

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# 6.3.1Visualizng Data (plotting lat vs temp)

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today

#info on datetime module https://docs.python.org/3.7/library/datetime.html#strftime-and-strptime-behavior
# Out:
# '09/25/22'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. wind speed
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()
