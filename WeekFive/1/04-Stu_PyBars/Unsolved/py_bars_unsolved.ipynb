# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_cities, color = 'g', alpha=0.5, align='center')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x2b6efcadb00>,
#   <matplotlib.axis.XTick at 0x2b6efcadac8>,
#   <matplotlib.axis.XTick at 0x2b6ed3caa58>,
#   <matplotlib.axis.XTick at 0x2b6efce5438>,
#   <matplotlib.axis.XTick at 0x2b6efce59e8>],
#  [Text(-1.0, 0, 'New Orleans'),
#   Text(0.0, 0, 'Milwaukee'),
#   Text(1.0, 0, 'Omaha'),
#   Text(2.0, 0, 'Pittsburgh'),
#   Text(3.0, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(0.75, len(x_axis)-0.25)
# Out:
# (0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0, max(bars_in_cities)+.4)
plt.show()

# %%
# Give the chart a title, x label, and y label
plt.title("Chart of Bars in Cities ")
plt.xlabel("Cities")
plt.ylabel("Count of Bars")
# Out:
# Text(83.83333333333334, 0.5, 'Count of Bars')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("../Images/test0919.png")
plt.show()
