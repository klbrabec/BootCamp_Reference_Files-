# %%
# # MatPlotLib 
# Another important package - used for data visualization. 

# Using documentation to solve problems should become second nature to you. 
# Don't stop practicing. 

# The important thing is knowing which technique to use for the scenario you are working on.
# HOW to do things is easier - using the documentation and materials that you have available. 

# Matplotlib - data visualization in python.
# Not the ONLY way - but one of the most popular ways 

# Summary statistics can be deceiving and not show the true picture of what the data actually is. 

# https://github.com/jumpingrivers/datasauRus/blob/main/man/figures/DinoSequential.gif
    
# MatPlot lib has official documentation
#     matplotlib.org 
    
#     Shows you sample code on how to create each plot. 

# Remember to treat each challenge as a learning opportunity. 

# Datasets include
#     DataFrames
#     Lists/Tuples/Dictionaries
#     NumPy Arrays 
    
# Visualizations 
#     All kinds 
    
# Heart of Matplotlib 
#     accepts many forms of input values. 
#     Enables custom colors, shapes and labels 
#     Does most of the plotting logistics for us - we just tell it what plot to make 
    
# Using Pyplot 
#     Create your dataset 
#     Generate your plot 
#         Tells mpl what data to use and which plot to make 
#     Customize your plot 
#         change the axes, label the figures, color the datapoints - make the plot as informative as possible. 
        
# Make sure any insights are actionable
# Make sure any charts are self explanatory 
#     You may not be the one presenting your data  - it should be easily understandable just looking at it. 
    
# np.arange(0,5,0.1) - creates an array going rom 0 to 5 in .1 increments. 

# Shift tab in Jupyter notebook will show you more information on how to use whatever 
# you've got highlighted (attributes, uses etc - this is embedded in the code for MPL)

# plt.xlabel - syntax to name X label 
# plt.ylabel - syntax to name Y label 

# LIST COMPREHENSION (RESEARCH)

# exponential_chart

# Sin_cos - 
# plotting two lines in a plot. 

# # Plot both of these lines so that they will appear on our final chart
# plt.plot(x_axis, sin)
# plt.plot(x_axis, cos)

# plt.show()

# The above code will include two lines in the plot (Sin/cos) 

# Most important is what gets displayed where (X axis/Y axis etc )
# You can customize pretty much anything when you are building a plot. 

# Check out the documentation to determine what looks best to you. 

# Magic Commands in MatPlotLib 
# %matplotlib notebook 
# Include this line to make plots interactive. 
# (Try this)
# Look for other magic commands. 
# These are similar to plugins used with applications. 

legendary_temp

Matplotlib is not just for line plots
    bar charts
    pie charts
    scatter plots 
    
what is the right choice of chart that you would use to convey your message to the stakeholders. 

What is the question that you are trying to answer with the chart? 

ex - how many sales did we have vs someone else?
    This would be the job for a bar chart. 
    
what's the market share that we hold against our competitors?
    This is a job for a pie chart 
    
where do values fall with respect to two factors?
    This would be a scatterplot. 
    
It's VERY important to choose the right plot for your dataset. 


Barcharts 
Would you be able to read in a list to populate xticks/yticks?
xlim/ylim - allows you to limit the spread of values on an axis. 

What happens if your data goes beyond your limitations? 

Sample barchart is not actionable. 
    What could we do to improve/convey what needs to be done with what we are showing? 
    ex - different colors for each bar. 
    Put data in ranking order (Highest to lowest)
    
Bar Charts - help to visualize Univariate Data 
    one variable or one type of measurement 
    
Bar Charts are not effective for bivariate data 
    Ex - number of ice cream bars sold vs daily temperature 
        Thing of examples where bar charts will be effective.
        
Pie Charts 
    

# # End Note Block
