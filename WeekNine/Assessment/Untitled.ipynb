# %% [markdown]
# read stations into dataframe

# %%
import pandas as pd
import csv
import os 

#establish dataframes
import_data = os.path.join("CTA_list_of_L_stops.csv")
import_data2 = os.path.join("CTA_ridership_daily_totals.csv")

stops_df = pd.read_csv(import_data)
rider_df = pd.read_csv(import_data2)

stops_df
# Out:
#      STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0      30162            W         18th (54th/Cermak-bound)
# 1      30161            E                18th (Loop-bound)
# 2      30022            N         35th/Archer (Loop-bound)
# 3      30023            S       35th/Archer (Midway-bound)
# 4      30214            S  35-Bronzeville-IIT (63rd-bound)
# ..       ...          ...                              ...
# 295    30105            N            Wilson (Howard-bound)
# 296    30239            N           Addison (O'Hare-bound)
# 297    30106            S              Wilson (95th-bound)
# 298    30383            N   Washington/Wabash (Outer Loop)
# 299    30385            S              Wilson (Loop-bound)
#
#              STATION_NAME                           STATION_DESCRIPTIVE_NAME  \
# 0                    18th                                   18th (Pink Line)
# 1                    18th                                   18th (Pink Line)
# 2             35th/Archer                          35th/Archer (Orange Line)
# 3             35th/Archer                          35th/Archer (Orange Line)
# 4    35th-Bronzeville-IIT                  35th-Bronzeville-IIT (Green Line)
# ..                    ...                                                ...
# 295                Wilson                        Wilson (Red & Purple Lines)
# 296               Addison                                Addison (Blue Line)
# 297                Wilson                        Wilson (Red & Purple Lines)
# 298     Washington/Wabash  Washington/Wabash (Brown, Green, Orange, Purpl...
# 299                Wilson                        Wilson (Red & Purple Lines)
#
#      MAP_ID   ADA    RED   BLUE      G    BRN      P   Pexp      Y    Pnk  \
# 0     40830  True  False  False  False  False  False  False  False   True
# 1     40830  True  False  False  False  False  False  False  False   True
# 2     40120  True  False  False  False  False  False  False  False  False
# 3     40120  True  False  False  False  False  False  False  False  False
# 4     41120  True  False  False   True  False  False  False  False  False
# ..      ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 295   40540  True   True  False  False  False  False  False  False  False
# 296   41240  True  False   True  False  False  False  False  False  False
# 297   40540  True   True  False  False  False  False  False  False  False
# 298   41700  True  False  False   True   True  False  False  False  False
# 299   40540  True  False  False  False  False  False   True  False  False
#
#          O                 Location
# 0    False  (41.857908, -87.669147)
# 1    False  (41.857908, -87.669147)
# 2     True  (41.829353, -87.680622)
# 3     True  (41.829353, -87.680622)
# 4    False  (41.831677, -87.625826)
# ..     ...                      ...
# 295  False  (41.964273, -87.657588)
# 296  False    (41.94738, -87.71906)
# 297  False  (41.964273, -87.657588)
# 298  False   (41.88322, -87.626189)
# 299  False  (41.964273, -87.657588)
#
# [300 rows x 17 columns]

# %%
stops = len(pd.unique(stops_df['MAP_ID']))
stops
# Out:
# 143

# %%
df = pd.merge(rider_df, stops_df, how='left', left_on='station_id', right_on='MAP_ID')
df[df['latitude'] < 41.881]['rides'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 df = pd.merge(rider_df, stops_df, how='left', left_on='station_id', right_on='MAP_ID')
# ----> 2 df[df['latitude'] < 41.881]['rides'].sum()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'latitude'

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import pandas as pd

# %%
database_path = "/Census.Data.sqlite"
engine = create_engine("sqlite:///Census_Data.sqlite")
conn = engine.connect()
conn

# %%
# reflect an existing database into a new model
# Reflecting a database into a new model essentially means to transfer the contents of the database into a different structure of data. 
Base = automap_base()
# reflect the tables
# prepare() function. By adding this code, we'll reflect the schema of our SQLite tables into our code and create mappings.
Base.prepare(engine, reflect=True)

session = Session(engine)
session

# %%
Base.classes.keys()
# Out:
# []

# %%
import pandas as pd
import re

dracula_df = pd.read_csv('dracula.txt', sep ='[\r\n]+', header=None, engine='python')
dracula_df.columns = ['text']
dracula_df

p = 'vampire\s+(\w+)'
dracula_df['text'].str.extractall(p, flags=re.I)[0].value_counts()
# Out:
# sleep      3
# in         2
# was        1
# which      1
# kind       1
# live       1
# can        1
# meant      1
# is         1
# coming     1
# baptism    1
# of         1
# Name: 0, dtype: int64

# %%
import pandas as pd
import
# Out:
#                                                     text
# 0                                                DRACULA
# 1                                                DRACULA
# 2                                                   _by_
# 3                                            Bram Stoker
# 4                               [Illustration: colophon]
# ...                                                  ...
# 13046  know what a brave and gallant woman his mother...
# 13047  sweetness and loving care; later on he will un...
# 13048  loved her, that they did dare much for her sake."
# 13049                                   JONATHAN HARKER.
# 13050                                            THE END
#
# [13051 rows x 1 columns]

# %%
l_stops_df = pd.read_csv('CTA_list_of_L_stops.csv')
station_bools = l_stops_df[['MAP_ID','ADA','RED','BLUE','G','BRN','P','Pexp','Y','Pnk','O']].groupby('MAP_ID').any()
l_stations_df = l_stops_df[['MAP_ID','STATION_NAME','STATION_DESCRIPTIVE_NAME','Location']] \
    .merge(station_bools, how='left', left_on='MAP_ID', right_index=True).drop_duplicates()

# %%
l_stations_df[['latitude','longitude']] = \
   l_stations_df['Location'].str.replace('\(|\)','',regex=True) \
   .str.split(',', expand=True).apply(pd.to_numeric)
l_stations_df.drop('Location', axis=1, inplace=True)

# %%
ridership_df = pd.read_csv('CTA_ridership_daily_totals.csv')

# %%
engine = create_engine(f"postgresql://postgres:postgres@localhost:5432/cta_db")
l_stations_df.to_sql(name='stations', con=engine, index=False)
ridership_df.to_sql(name='ridership', con=engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [99], in <cell line: 1>()
# ----> 1 engine = create_engine(f"postgresql://postgres:postgres@localhost:5432/cta_db")
#       2 l_stations_df.to_sql(name='stations', con=engine, index=False)
#       3 ridership_df.to_sql(name='ridership', con=engine, index=False)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
#     304             messages[m],
#     305             versions[m],
#     306             version_warnings[m],
#     307             stacklevel=3,
#     308         )
# --> 309 return fn(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\sqlalchemy\engine\create.py:560, in create_engine(url, **kwargs)
#     558         if k in kwargs:
#     559             dbapi_args[k] = pop_kwarg(k)
# --> 560     dbapi = dialect_cls.dbapi(**dbapi_args)
#     562 dialect_args["dbapi"] = dbapi
#     564 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:782, in PGDialect_psycopg2.dbapi(cls)
#     780 @classmethod
#     781 def dbapi(cls):
# --> 782     import psycopg2
#     784     return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'
